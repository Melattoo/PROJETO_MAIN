# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_olist_customers_dataset = pd.read_csv('/home/melatto/Documentos/projeto_main/data/olist_customers_dataset.csv')
df_olist_order_items_dataset = pd.read_csv('/home/melatto/Documentos/projeto_main/data/olist_order_items_dataset.csv')
df_olist_geolocation_dataset = pd.read_csv('/home/melatto/Documentos/projeto_main/data/olist_geolocation_dataset.csv')
df_olist_order_payments_dataset = pd.read_csv('/home/melatto/Documentos/projeto_main/data/olist_order_payments_dataset.csv')
df_olist_order_reviews_dataset = pd.read_csv('/home/melatto/Documentos/projeto_main/data/olist_order_reviews_dataset.csv')
df_olist_orders_dataset = pd.read_csv('/home/melatto/Documentos/projeto_main/data/olist_orders_dataset.csv')
df_olist_products_dataset = pd.read_csv('/home/melatto/Documentos/projeto_main/data/olist_products_dataset.csv')
df_olist_sellers_dataset = pd.read_csv('/home/melatto/Documentos/projeto_main/data/olist_products_dataset.csv')
df_product_category_name_translation = pd.read_csv('/home/melatto/Documentos/projeto_main/data/product_category_name_translation.csv')

# %%
#CONTAR PEDIDOS POR MÊS E ORDENAR PARA QUANDO CRIAR O GRAFICO ELE FICAR EM ORDEM CRONOLOGICA

df_olist_orders_dataset['order_purchase_timestamp'] = pd.to_datetime(df_olist_orders_dataset['order_purchase_timestamp'])
df_olist_orders_dataset['mes_ano'] = df_olist_orders_dataset['order_purchase_timestamp'].dt.to_period('M')
vendas_por_mes = df_olist_orders_dataset['mes_ano'].value_counts().sort_index()
print(vendas_por_mes)

# %%
#CRIAR UM GRFICO PARA DEMONSTRAR A QUANTIDADE
plt.figure(figsize=(12, 6))
vendas_por_mes.plot(kind='line', marker='o', color='blue', linestyle='-', linewidth=2)
plt.title('Evolução Mensal de Pedidos', fontsize=16, pad=20)
plt.xlabel('Mês/Ano', fontsize=12)
plt.ylabel('Número de Pedidos', fontsize=12)
plt.tight_layout() #IMPORTANTE PARA NAO "CORTAR" O GRAFICO
plt.show()

# %%
#quais produtos são mais vendidos - porem ainda há necessidade de concatenar com a planilha "df_olist_products_dataset" 
produtos_mais_vendidos = df_olist_order_items_dataset['product_id'].value_counts().head(10)
print(produtos_mais_vendidos)
# Out:
# product_id
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
# 53759a2ecddad2bb87a079a1f1519f73    373
# d1c427060a0f73f6b889a5c7c61f2ac4    343
# 53b36df67ebb7c41585e8d54d6772e08    323
# 154e7e31ebfa092203795c972e5804a6    281
# 3dd2a17168ec895c781a9191c1e95ad7    274
# Name: count, dtype: int64

# %%
#quais categorias existem

# %%
#quais tipo de pedido recebem nota baixa

# %%
#qual perfil de quem mais compra
